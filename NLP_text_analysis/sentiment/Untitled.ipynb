# %%
# Model 1- Classification model using sci-kit learn machine learning model:Classify the text as positive or negative automatically
# Model 1- Automatically classfiy the text comments as positive or negative
# Model 2- Classify the tex as group of category

# %% [markdown]
# # Outlines
# 1. Data preparation
# 2. Model selection
# 3. Analysis and evaluation
# 4. Improveing the model
# 5. Saving the model

# %% [markdown]
# ### Data set
# Source: amazon.com, the amazon review as training data
# full data source: http://jmcauley.ucsd.edu/data/amazon/
